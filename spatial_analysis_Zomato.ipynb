# %% [markdown]
# <a href="https://colab.research.google.com/github/grymoon5/Zomato-analysis/blob/main/spatial_analysis_Zomato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Spatial Analysis/zomato.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari

# %%
data.columns

# %%
data.shape

# %%
data.duplicated().sum()

# %%
data.isnull().sum()

# %%
data.dropna(subset=['location', inplace = True])

# %%
df = data.copy()

# %%
data['location'] + ', Bangalore, Karnataka, India'
# Out:
# 0                Banashankari, Bangalore, Karnataka, India
# 1                Banashankari, Bangalore, Karnataka, India
# 2                Banashankari, Bangalore, Karnataka, India
# 3                Banashankari, Bangalore, Karnataka, India
# 4                Basavanagudi, Bangalore, Karnataka, India
#                                ...
# 51712              Whitefield, Bangalore, Karnataka, India
# 51713              Whitefield, Bangalore, Karnataka, India
# 51714              Whitefield, Bangalore, Karnataka, India
# 51715    ITPL Main Road, Whitefield, Bangalore, Karnata...
# 51716    ITPL Main Road, Whitefield, Bangalore, Karnata...
# Name: location, Length: 51717, dtype: object

# %%
df.dytypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
rest_loc = pd.DataFrame()

# %%
rest_loc['Name'] = df['location'].unique()

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="app", timeout=None )

# %%
lat = []
lon = []

for name in rest_loc['Name']:
    location = geolocator.geocode(name)

    if location is None:
        lat.append(np.nan)
        lon.append(np.nan)

    else:
      lat.append(location.latitude)
      lon.append(location.longitude)

# %%
print(lat)
# Out:
# [12.9278196, 12.9417261, 12.9466619, 12.9292731, 12.9067683, 12.9274413, 23.1883478, 12.9055682, 12.9096941, 12.9881567, 39.7688062, 12.9527068, 12.9333792, 45.95454, 12.9235172, 13.1273532, 34.220389, 17.2510682, 12.8436448, 29.1523467, 12.9552572, 12.9243992, 12.9489339, 22.478459, 12.9348429, 12.9408685, 40.6090264, 12.9364846, 13.0394104, 12.9327778, 12.9361208, 44.3731286, 12.8504319, 7.1228505, 12.9732913, 12.9277245, 12.9975851, 13.0227204, 12.9755264, -36.9749169, -36.8868048, 40.7173762, 12.9778793, 13.0529766, 18.5325915, 12.9837535, 51.4066407, 12.9814395, 1.3069674, 51.5183953, 12.9921738, 13.031992, 12.9624669, 12.945245, 12.9678074, 12.9834863, 13.0027353, 16.7044988, 13.0148544, 12.9390255, 37.5339963, 12.957998, 12.9896451, 30.1915796, 12.9652094, 12.9706827, 12.9589491, 13.007516, 12.9243692, 12.9282918, 12.9357366, 12.8866823, 13.0005359, 13.0141618, 12.9881567, 23.3839376, 13.037077, 13.0221416, 13.0167862, 13.0784743, nan, 12.8744383, 12.9846713, 13.0382184, 12.9176571, 13.0010431, 15.8782951, 12.9911804, 13.0221838, 13.0096524, 12.975608, 13.1006982, 17.2569932, 13.0330515]

# %%
rest_loc['lat'] = lat
rest_loc['lon'] = lon

# %%
rest_loc
# Out:
#                   Name        lat        lon
# 0         Banashankari  12.927820  77.556621
# 1         Basavanagudi  12.941726  77.575502
# 2          Mysore Road  12.946662  77.530090
# 3            Jayanagar  12.929273  77.582423
# 4   Kumaraswamy Layout  12.906768  77.559502
# ..                 ...        ...        ...
# 89      West Bangalore  13.009652  77.553054
# 90         Magadi Road  12.975608  77.555356
# 91           Yelahanka  13.100698  77.596345
# 92      Sahakara Nagar  17.256993  80.153666
# 93              Peenya  13.033051  77.533223
#
# [94 rows x 3 columns]

# %%
#find out the total missing values
rest_loc.isnull().sum()
# Out:
# Name    1
# lat     1
# lon     1
# dtype: int64

# %%
#find the rows that has the missing value
rest_loc[rest_loc['lat'].isnull()]
# Out:
#                Name  lat  lon
# 80  Rammurthy Nagar  NaN  NaN

# %%
#search for the coordinates of the place and add in the missing values
rest_loc['lat'][80] = 13.0163
# Out:
# /tmp/ipython-input-44-3671083539.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   rest_loc['lat'][80] = 13.0163
# /tmp/ipython-input-44-3671083539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rest_loc['lat'][80] = 13.0163

# %%
rest_loc['lon'][80] = 77.6785
# Out:
# /tmp/ipython-input-45-2124233472.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   rest_loc['lon'][80] = 77.6785
# /tmp/ipython-input-45-2124233472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rest_loc['lon'][80] = 77.6785

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # How to write structured queries

# %%
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari

# %%
geolocator = Nominatim(user_agent="app", timeout=None )

# %%
df['address'][0]
# Out:
# '942, 21st Main Road, 2nd Stage, Banashankari, Bangalore'

# %%
loc = geolocator.geocode(df['address'][0])

# %%
hasattr(loc, 'latitude') #hasattr is the built-in function to check if the object has a specific attribute
# Out:
# False

# %%
address = {'street':'21st Main Road' , 'city': 'Bangalore' , 'country': 'India' , 'state': 'Karnataka'}

# %%
address_geocode = geolocator.geocode(address)

# %%
hasattr(address_geocode , 'latitude')
# Out:
# True

# %%
hasattr(address_geocode , 'longitude')
# Out:
# True

# %%
address_geocode.latitude
# Out:
# 13.0041365

# %%
address_geocode.longitude
# Out:
# 77.5606591

# %%
df['location'].value_counts()
# Out:
# location
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# Yelahanka                   6
# West Bangalore              6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: count, Length: 93, dtype: int64

# %%
type(df['location'].value_counts())
# Out:
# pandas.core.series.Series

# %%
Rest_locations = df['location'].value_counts().reset_index()

# %%
Rest_locations.columns = ['Name', 'count']

# %%
Rest_locations
# Out:
#                      Name  count
# 0                     BTM   5124
# 1                     HSR   2523
# 2   Koramangala 5th Block   2504
# 3                JP Nagar   2235
# 4              Whitefield   2144
# ..                    ...    ...
# 88              Yelahanka      6
# 89         West Bangalore      6
# 90                 Jakkur      3
# 91   Rajarajeshwari Nagar      2
# 92                 Peenya      1
#
# [93 rows x 2 columns]

# %%
rest_loc
# Out:
#                   Name        lat        lon
# 0         Banashankari  12.927820  77.556621
# 1         Basavanagudi  12.941726  77.575502
# 2          Mysore Road  12.946662  77.530090
# 3            Jayanagar  12.929273  77.582423
# 4   Kumaraswamy Layout  12.906768  77.559502
# ..                 ...        ...        ...
# 89      West Bangalore  13.009652  77.553054
# 90         Magadi Road  12.975608  77.555356
# 91           Yelahanka  13.100698  77.596345
# 92      Sahakara Nagar  17.256993  80.153666
# 93              Peenya  13.033051  77.533223
#
# [94 rows x 3 columns]

# %%
Beng_rest_locations = Rest_locations.merge( rest_loc, on="Name")

# %%
type(Beng_rest_locations)
# Out:
# pandas.core.frame.DataFrame

# %%
Beng_rest_locations.head(5)
# Out:
#                     Name  count        lat         lon
# 0                    BTM   5124  45.954540 -112.496554
# 1                    HSR   2523  29.152347   75.724580
# 2  Koramangala 5th Block   2504  12.934843   77.618977
# 3               JP Nagar   2235  12.909694   77.586607
# 4             Whitefield   2144  44.373129  -71.611966

# %% [markdown]
# How to create a map
# 1. Basemap
#
# *   define
#
# 2. Map your values

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.6.15)

# %%
import folium

# %%
def Generate_basemap():
    basemap = folium.Map(Location=[12.97 , 77.59])
    return basemap

# %%
basemap = Generate_basemap()

# %%
from folium.plugins import HeatMap

# %%
Beng_rest_locations.columns
# Out:
# Index(['Name', 'count', 'lat', 'lon'], dtype='object')

# %%
Beng_rest_locations[['lat', 'lon', 'count']]
# Out:
#           lat         lon  count
# 0   45.954540 -112.496554   5124
# 1   29.152347   75.724580   2523
# 2   12.934843   77.618977   2504
# 3   12.909694   77.586607   2235
# 4   44.373129  -71.611966   2144
# ..        ...         ...    ...
# 88  13.100698   77.596345      6
# 89  13.009652   77.553054      6
# 90  13.078474   77.606894      3
# 91  12.927441   77.515522      2
# 92  13.033051   77.533223      1
#
# [93 rows x 3 columns]

# %%
HeatMap(Beng_rest_locations[['lat', 'lon', 'count']]).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_825c5faaf44f65d2122a0512f2ac8b2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_825c5faaf44f65d2122a0512f2ac8b2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_825c5faaf44f65d2122a0512f2ac8b2f = L.map(
#                 &quot;map_825c5faaf44f65d2122a0512f2ac8b2f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;Location&quot;: [
# 12.97,
# 77.59,
# ],
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1bce8d32891a3182f43755dc85bda97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1bce8d32891a3182f43755dc85bda97.addTo(map_825c5faaf44f65d2122a0512f2ac8b2f);
#
#
#             var heat_map_05b69bbaa457749ce88133d5c533d8d9 = L.heatLayer(
#                 [[45.95454, -112.4965538, 5124.0], [29.1523467, 75.7245798, 2523.0], [12.9348429, 77.6189768, 2504.0], [12.9096941, 77.5866067, 2235.0], [44.3731286, -71.6119661, 2144.0], [12.9732913, 77.6404672, 2083.0], [12.9292731, 77.5824229, 1926.0], [12.9552572, 77.6984163, 1846.0], [12.9333792, 77.6011086, 1630.0], [12.9361208, 77.6671843, 1286.0], [12.8436448, 77.6686835, 1258.0], [12.9277245, 77.6327822, 1238.0], [-36.9749169, 174.7822815, 1218.0], [12.9364846, 77.6134783, 1181.0], [12.9390255, 77.6238477, 1156.0], [12.9243992, 77.6511213, 1065.0], [12.9778793, 77.6246697, 1023.0], [12.9327778, 77.6294052, 1017.0], [12.9755264, 77.6067902, 918.0], [12.9278196, 77.556621, 906.0], [13.0221416, 77.6403368, 853.0], [40.6090264, -74.0905412, 812.0], [12.9975851, 77.6136744, 727.0], [13.0027353, 77.5703253, 725.0], [12.9417261, 77.5755021, 684.0], [13.0529766, 77.6204671, 675.0], [13.0141618, 77.6518539, 664.0], [12.9652094, 77.717936, 658.0], [13.0167862, 77.5726166, 649.0], [13.0148544, 77.6382029, 648.0], [13.0005359, 77.5496996, 591.0], [40.7173762, -74.0060045, 569.0], [-36.8868048, 174.6376724, 529.0], [22.478459, 88.3541291, 511.0], [18.5325915, 73.8513115, 499.0], [12.9624669, 77.6381958, 496.0], [12.9814395, 77.5986425, 491.0], [7.1228505, 125.6540124, 446.0], [12.945245, 77.6274776, 439.0], [51.5183953, -0.0744447, 370.0], [51.4066407, -0.1585786, 352.0], [12.9408685, 77.617338, 320.0], [12.9921738, 77.591459, 295.0], [12.9678074, 77.6568367, 272.0], [12.9489339, 77.5968273, 246.0], [13.1273532, 77.359826, 238.0], [12.9282918, 77.6254034, 216.0], [12.9067683, 77.5595021, 195.0], [12.8744383, 77.5579029, 194.0], [12.9911804, 77.5448918, 191.0], [23.3839376, 74.2990136, 187.0], [16.7044988, 80.5466724, 165.0], [13.037077, 77.6413572, 161.0], [37.5339963, -82.0998518, 155.0], [13.031992, 77.6280789, 153.0], [12.9837535, 77.5942295, 151.0], [1.3069674, 103.8499255, 139.0], [39.7688062, -86.1534508, 126.0], [13.0221838, 77.5530824, 119.0], [12.9589491, 77.7467508, 117.0], [12.9706827, 77.7124547, 113.0], [12.9881567, 77.6226, 107.0], [12.8866823, 77.6415249, 102.0], [12.9243692, 77.6242433, 102.0], [12.9846713, 77.6790908, 101.0], [17.2510682, 80.1651978, 90.0], [13.0227204, 77.595715, 80.0], [23.1883478, 79.9092722, 80.0], [30.1915796, 74.9408769, 76.0], [15.8782951, 74.5084834, 63.0], [17.2569932, 80.1536665, 53.0], [12.9357366, 77.624081, 48.0], [12.8504319, 77.6601401, 44.0], [13.0394104, 77.5197351, 38.0], [12.975608, 77.5553564, 34.0], [13.0163, 77.6785, 32.0], [13.0010431, 77.5841835, 27.0], [12.957998, 77.6037312, 27.0], [12.9466619, 77.5300896, 22.0], [12.9834863, 77.6390581, 22.0], [12.9235172, 77.5761812, 19.0], [13.007516, 77.695935, 18.0], [12.9055682, 77.5455438, 17.0], [13.0382184, 77.5919, 14.0], [12.9881567, 77.6226, 14.0], [12.9176571, 77.4837568, 9.0], [12.9527068, 77.5209428, 9.0], [12.9896451, 77.5727101, 8.0], [13.1006982, 77.5963454, 6.0], [13.0096524, 77.5530535, 6.0], [13.0784743, 77.6068938, 3.0], [12.9274413, 77.5155224, 2.0], [13.0330515, 77.5332233, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_05b69bbaa457749ce88133d5c533d8d9.addTo(map_825c5faaf44f65d2122a0512f2ac8b2f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import FastMarkerCluster

# %%
basemap = Generate_basemap()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_677672b149c1312e86b4cc1a8654bdbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_677672b149c1312e86b4cc1a8654bdbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_677672b149c1312e86b4cc1a8654bdbd = L.map(
#                 &quot;map_677672b149c1312e86b4cc1a8654bdbd&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;Location&quot;: [
# 12.97,
# 77.59,
# ],
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a84c602d010aec5da9a12f035badf0da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a84c602d010aec5da9a12f035badf0da.addTo(map_677672b149c1312e86b4cc1a8654bdbd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
FastMarkerCluster(Beng_rest_locations[['lat', 'lon', 'count']])

# %%
Beng_rest_locations
# Out:
#                      Name  count        lat         lon
# 0                     BTM   5124  45.954540 -112.496554
# 1                     HSR   2523  29.152347   75.724580
# 2   Koramangala 5th Block   2504  12.934843   77.618977
# 3                JP Nagar   2235  12.909694   77.586607
# 4              Whitefield   2144  44.373129  -71.611966
# ..                    ...    ...        ...         ...
# 88              Yelahanka      6  13.100698   77.596345
# 89         West Bangalore      6  13.009652   77.553054
# 90                 Jakkur      3  13.078474   77.606894
# 91   Rajarajeshwari Nagar      2  12.927441   77.515522
# 92                 Peenya      1  13.033051   77.533223
#
# [93 rows x 4 columns]

# %%
basemap = Generate_basemap()

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beee3414911c21caa1288a43d141d9cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beee3414911c21caa1288a43d141d9cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beee3414911c21caa1288a43d141d9cf = L.map(
#                 &quot;map_beee3414911c21caa1288a43d141d9cf&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;Location&quot;: [
# 12.97,
# 77.59,
# ],
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8adbbc193d29a4b8348a3356f6148120 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8adbbc193d29a4b8348a3356f6148120.addTo(map_beee3414911c21caa1288a43d141d9cf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for idx, row in Beng_rest_locations.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['count']).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beee3414911c21caa1288a43d141d9cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beee3414911c21caa1288a43d141d9cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beee3414911c21caa1288a43d141d9cf = L.map(
#                 &quot;map_beee3414911c21caa1288a43d141d9cf&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;Location&quot;: [
# 12.97,
# 77.59,
# ],
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8adbbc193d29a4b8348a3356f6148120 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8adbbc193d29a4b8348a3356f6148120.addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#             tile_layer_8adbbc193d29a4b8348a3356f6148120.addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#             var marker_a56354ed828aa6783a8dbd82a93f9fb0 = L.marker(
#                 [45.95454, -112.4965538],
#                 {
# }
#             ).addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#         var popup_8d28176f0099de8b0ecc183184e134d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4062f243d653118b9ac1b815454c81a6 = $(`&lt;div id=&quot;html_4062f243d653118b9ac1b815454c81a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5124&lt;/div&gt;`)[0];
#                 popup_8d28176f0099de8b0ecc183184e134d8.setContent(html_4062f243d653118b9ac1b815454c81a6);
#
#
#
#         marker_a56354ed828aa6783a8dbd82a93f9fb0.bindPopup(popup_8d28176f0099de8b0ecc183184e134d8)
#         ;
#
#
#
#
#             var marker_8216e4e52244593d03d9d5f57891b14b = L.marker(
#                 [29.1523467, 75.7245798],
#                 {
# }
#             ).addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#         var popup_0ddbd139b5e8e7e63a7d549053744fda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_107a8c545cd40c072fd69028e5f1603d = $(`&lt;div id=&quot;html_107a8c545cd40c072fd69028e5f1603d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2523&lt;/div&gt;`)[0];
#                 popup_0ddbd139b5e8e7e63a7d549053744fda.setContent(html_107a8c545cd40c072fd69028e5f1603d);
#
#
#
#         marker_8216e4e52244593d03d9d5f57891b14b.bindPopup(popup_0ddbd139b5e8e7e63a7d549053744fda)
#         ;
#
#
#
#
#             var marker_5224eb47619f9fc951f3c384255725ae = L.marker(
#                 [12.9348429, 77.6189768],
#                 {
# }
#             ).addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#         var popup_e2ce2ed76e4f457d23de9b83a07d5815 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5171f808ef689d239e837f584612bd07 = $(`&lt;div id=&quot;html_5171f808ef689d239e837f584612bd07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2504&lt;/div&gt;`)[0];
#                 popup_e2ce2ed76e4f457d23de9b83a07d5815.setContent(html_5171f808ef689d239e837f584612bd07);
#
#
#
#         marker_5224eb47619f9fc951f3c384255725ae.bindPopup(popup_e2ce2ed76e4f457d23de9b83a07d5815)
#         ;
#
#
#
#
#             var marker_761ebf3aedec5466305b788db42412f6 = L.marker(
#                 [12.9096941, 77.5866067],
#                 {
# }
#             ).addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#         var popup_89d172062f7eb7e47b13908cdb5316ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbf604d1da4151fc8df028773aae5146 = $(`&lt;div id=&quot;html_dbf604d1da4151fc8df028773aae5146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2235&lt;/div&gt;`)[0];
#                 popup_89d172062f7eb7e47b13908cdb5316ad.setContent(html_dbf604d1da4151fc8df028773aae5146);
#
#
#
#         marker_761ebf3aedec5466305b788db42412f6.bindPopup(popup_89d172062f7eb7e47b13908cdb5316ad)
#         ;
#
#
#
#
#             var marker_3ed57078797666572d262fbee29e3d03 = L.marker(
#                 [44.3731286, -71.6119661],
#                 {
# }
#             ).addTo(map_beee3414911c21caa1288a43d141d9cf);
#
#
#         var popup_ccd4fbc813c4bc0d3e5de70b19eaf5f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4caf9555afdff15cb484b80a4d42d3cc = $(`&lt;div id=&quot;html_4caf9555afdff15cb484b80a4d42d3cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2144&lt;/div&gt;`)[0];
#                 popup_ccd4fbc813c4

# %%
df.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari

# %%
df['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51717, dtype: object

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['rate'].isnull().sum()
# Out:
# np.int64(7775)

# %%
df['rate'].isnull().sum()/len(df)*100
# Out:
# np.float64(15.033741322969234)

# %%
df.dropna(subset = ['rate'], inplace = True)

# %%
df['rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df.replace('NEW' , np.nan, inplace = True)
df.replace('-' , np.nan, inplace = True)

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '0', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['rating'] = df['rate'].str.replace('/5' , '').str.strip()

# %%
df['rating'] = df['rating'].astype(float)

# %%
df['rating'].dtype
# Out:
# dtype('O')

# %%
df['rating'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df.head(4)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
# 3           No         No  3.7/5     88                  +91 9620009302
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
#
#   listed_in(type) listed_in(city)  rating
# 0          Buffet    Banashankari     4.1
# 1          Buffet    Banashankari     4.1
# 2          Buffet    Banashankari     3.8
# 3          Buffet    Banashankari     3.7

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)', 'rating'],
#       dtype='object')

# %%
grp_df = df.groupby(['location'], as_index= False).agg({'rating': 'mean' , 'name':'size'})

# %%
grp_df.columns = ['Name', 'avg_rating', 'count']

# %%
grp_df['count']>400
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 87    False
# 88     True
# 89    False
# 90    False
# 91    False
# Name: count, Length: 92, dtype: bool

# %%
temp_df = grp_df[grp_df['count']>400]

# %%
temp_df.shape
# Out:
# (35, 3)

# %%
Ratings_locations = temp_df.merge(rest_loc, on='Name')

# %%
Ratings_locations
# Out:
#                      Name  avg_rating  count        lat         lon
# 0                     BTM    3.296128   4261  45.954540 -112.496554
# 1            Banashankari    3.373292    805  12.927820   77.556621
# 2               Banaswadi    3.362926    499  13.014162   77.651854
# 3       Bannerghatta Road    3.271677   1324  12.933379   77.601109
# 4            Basavanagudi    3.478185    628  12.941726   77.575502
# 5               Bellandur    3.309833   1078  12.936121   77.667184
# 6            Brigade Road    3.595849   1084 -36.974917  174.782282
# 7             Brookefield    3.374699    581  12.965209   77.717936
# 8           Church Street    3.963091    550  40.717376  -74.006005
# 9         Cunningham Road    3.901053    475  12.981440   77.598642
# 10                 Domlur    3.385548    429  12.962467   77.638196
# 11        Electronic City    3.041909    964  12.843645   77.668684
# 12            Frazer Town    3.564879    578  12.997585   77.613674
# 13                    HSR    3.484070   2128  29.152347   75.724580
# 14            Indiranagar    3.652169   1936  12.973291   77.640467
# 15               JP Nagar    3.412926   1849  12.909694   77.586607
# 16              Jayanagar    3.615250   1718  12.929273   77.582423
# 17           Kalyan Nagar    3.529144    748  13.022142   77.640337
# 18           Kammanahalli    3.499810    525  13.014854   77.638203
# 19  Koramangala 1st Block    3.263938    965  12.927725   77.632782
# 20  Koramangala 4th Block    3.814352    864  12.932778   77.629405
# 21  Koramangala 5th Block    3.901512   2381  12.934843   77.618977
# 22  Koramangala 6th Block    3.662466   1111  12.939025   77.623848
# 23  Koramangala 7th Block    3.747842   1089  12.936485   77.613478
# 24           Lavelle Road    4.042886    499 -36.886805  174.637672
# 25                MG Road    3.740550    836  12.975526   77.606790
# 26           Malleshwaram    3.668237    658  13.002735   77.570325
# 27           Marathahalli    3.400532   1503  12.955257   77.698416
# 28           New BEL Road    3.583174    523  13.016786   77.572617
# 29            Rajajinagar    3.422382    487  13.000536   77.549700
# 30         Residency Road    3.844572    608  13.052977   77.620467
# 31          Richmond Road    3.688013    634  40.609026  -74.090541
# 32          Sarjapur Road    3.473558    919  12.924399   77.651121
# 33                 Ulsoor    3.541398    901  12.977879   77.624670
# 34             Whitefield    3.384170   1693  44.373129  -71.611966

# %%
basemap =  Generate_basemap()

# %%
HeatMap(Ratings_locations[['lat', 'lon', 'avg_rating']]).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1273f9553ba7e7ebd8c7378852cc66f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1273f9553ba7e7ebd8c7378852cc66f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1273f9553ba7e7ebd8c7378852cc66f = L.map(
#                 &quot;map_d1273f9553ba7e7ebd8c7378852cc66f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;Location&quot;: [
# 12.97,
# 77.59,
# ],
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e97b59d10e514feeda945f1057163a69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e97b59d10e514feeda945f1057163a69.addTo(map_d1273f9553ba7e7ebd8c7378852cc66f);
#
#
#             var heat_map_4b6fb6188138b231e8e75139dbe11ccb = L.heatLayer(
#                 [[45.95454, -112.4965538, 3.2961276695611357], [12.9278196, 77.556621, 3.3732919254658387], [13.0141618, 77.6518539, 3.3629258517034066], [12.9333792, 77.6011086, 3.2716767371601208], [12.9417261, 77.5755021, 3.4781847133757964], [12.9361208, 77.6671843, 3.3098330241187384], [-36.9749169, 174.7822815, 3.595848708487085], [12.9652094, 77.717936, 3.374698795180723], [40.7173762, -74.0060045, 3.9630909090909086], [12.9814395, 77.5986425, 3.9010526315789473], [12.9624669, 77.6381958, 3.385547785547786], [12.8436448, 77.6686835, 3.0419087136929464], [12.9975851, 77.6136744, 3.564878892733564], [29.1523467, 75.7245798, 3.4840695488721805], [12.9732913, 77.6404672, 3.6521694214876037], [12.9096941, 77.5866067, 3.4129259058950785], [12.9292731, 77.5824229, 3.6152502910360886], [13.0221416, 77.6403368, 3.529144385026738], [13.0148544, 77.6382029, 3.499809523809524], [12.9277245, 77.6327822, 3.2639378238341967], [12.9327778, 77.6294052, 3.8143518518518515], [12.9348429, 77.6189768, 3.901511969760605], [12.9390255, 77.6238477, 3.6624662466246622], [12.9364846, 77.6134783, 3.7478420569329662], [-36.8868048, 174.6376724, 4.042885771543086], [12.9755264, 77.6067902, 3.74055023923445], [13.0027353, 77.5703253, 3.668237082066869], [12.9552572, 77.6984163, 3.4005322687957418], [13.0167862, 77.5726166, 3.5831739961759084], [13.0005359, 77.5496996, 3.422381930184805], [13.0529766, 77.6204671, 3.8445723684210527], [40.6090264, -74.0905412, 3.6880126182965296], [12.9243992, 77.6511213, 3.4735582154515776], [12.9778793, 77.6246697, 3.5413984461709216], [44.3731286, -71.6119661, 3.384170112226816]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_4b6fb6188138b231e8e75139dbe11ccb.addTo(map_d1273f9553ba7e7ebd8c7378852cc66f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
